# %%
from sklearn.model_selection import train_test_split
import numpy as np
import math
from torch.utils.data import DataLoader, Dataset
import torch
import matplotlib.pyplot as plt
import torch.nn.functional as F

from _basicClasses import TimeSeriesDatasetSingleSubject, GlobalModel, LocalModel, EventModel, TimeSeriesDataset
from _train_pred import predict, evaluate, train, split_dataset
import glob
import pandas as pd
import os

# %%
import orjson
from gluonts.dataset.repository.datasets import get_dataset
from gluonts.dataset.util import to_pandas

# %%
K = 5  # Number of final factors 
# Parameters for the dataset
# J = 5 # Number of subjects
D = 321  # Number of features
T = 21044   # Number of time points
C = 1   # Number of categorical variables
C_levels = 3
num_epochs = 100  # Number of epochs for training
hidden_size_global = 100 
hidden_size_local = 5
train_ratio=.8
batch_size = 32

# %%
csv_directory = './uber_data_files/'  

# Initialize a list to hold all time series data
all_series = []

# List all CSV files in the directory
csv_files = glob.glob(os.path.join(csv_directory, '*.csv'))

for file_path in csv_files:
    # Read the CSV file
    df = pd.read_csv(file_path)
    
    # Assuming 'traffic_volume' is the column with your time series data
    series = df['uber_ride'].values
    
    series = (series - series.mean())/series.std()

    # Convert the series to a PyTorch tensor and add a dimension to make it (T, 1)
    tensor_series = torch.tensor(series, dtype=torch.float32).unsqueeze(1)
    
    # Append the tensor to the list
    all_series.append(tensor_series)

max_length = max([s.size(0) for s in all_series])  # Find the max length
padded_series = [F.pad(s, (0, 0, 0, max_length - s.size(0))) for s in all_series]  # Pad each tensor to max_length

# Now concatenate
X = torch.cat(padded_series, dim=1)

# X is now a tensor of shape (T, D) where T is the total length of all series combined and D=1
print(X.shape)
# Out:
# torch.Size([21044, 321])

# %%
print(X[:,100].shape)
Y = X[:,100]
binary_events =  torch.zeros(T, 1)
cat_vars = torch.zeros(T, 1)
dataset = TimeSeriesDatasetSingleSubject(X[:-1], Y[:-1], X[1:], Y[1:], cat_vars, binary_events)
# Out:
# torch.Size([21044])

# %%
train_dataset, test_dataset = split_dataset(dataset, r=0.2)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
len(test_dataset)
# Out:
# 4209

# %%
# Assuming the model instances are created like this:
global_model = GlobalModel(D, hidden_size_global, K)

# 1 + num_categorical_features: 
local_model = LocalModel(1 + C, hidden_size_local)
# event_model = EventModel(C, hidden_dim= 10)
event_model = EventModel(1 + C, hidden_size_local)

optimizer = torch.optim.Adam(list(global_model.parameters()) + list(local_model.parameters()) + list(event_model.parameters()), lr=0.005)

# %%
# For early stopping
patience = 10
min_loss = float('inf')
best_model = None
best_epoch = 0

for epoch in range(num_epochs):
    train_loss = train(global_model, local_model, event_model, optimizer, train_dataloader)
    test_loss = evaluate(global_model, local_model, event_model, test_dataloader)
    print(f'Epoch {epoch+1}, Train Loss: {train_loss:.4f}, Test Loss: {test_loss:.4f}')
# Out:
# Epoch 1, Train Loss: 1.5691, Test Loss: 1.3016
# Epoch 2, Train Loss: 1.1836, Test Loss: 1.2573
# Epoch 3, Train Loss: 0.9790, Test Loss: 0.8744
# Epoch 4, Train Loss: 0.9066, Test Loss: 1.2892
# Epoch 5, Train Loss: 0.7964, Test Loss: 1.4118
# Epoch 6, Train Loss: 0.7687, Test Loss: 0.8805
# Epoch 55, Train Loss: 0.5359, Test Loss: 1.0281
# Epoch 56, Train Loss: 0.5428, Test Loss: 1.1183
# Epoch 57, Train Loss: 0.5378, Test Loss: 1.0621
# Epoch 58, Train Loss: 0.5363, Test Loss: 0.9719
# Epoch 59, Train Loss: 0.5443, Test Loss: 1.0871
# Epoch 60, Train Loss: 0.5354, Test Loss: 1.1449
# Epoch 61, Train Loss: 0.5176, Test Loss: 1.0355
# Epoch 62, Train Loss: 0.5296, Test Loss: 1.2129
# Epoch 63, Train Loss: 0.5077, Test Loss: 0.9950
# Epoch 64, Train Loss: 0.5384, Test Loss: 1.0427
# Epoch 65, Train Loss: 0.5171, Test Loss: 0.9583
# Epoch 66, Train Loss: 0.5178, Test Loss: 0.9427
# Epoch 67, Train Loss: 0.5168, Test Loss: 1.3814
# Epoch 68, Train Loss: 0.5244, Test Loss: 1.0350
# Epoch 69, Train Loss: 0.5260, Test Loss: 0.9748
# Epoch 70, Train Loss: 0.5183, Test Loss: 1.2470
# Epoch 71, Train Loss: 0.5409, Test Loss: 0.8557
# Epoch 72, Train Loss: 0.5229, Test Loss: 1.0342
# Epoch 73, Train Loss: 0.5479, Test Loss: 1.0278
# Epoch 74, Train Loss: 0.5140, Test Loss: 0.9290
# Epoch 75, Train Loss: 0.5105, Test Loss: 0.9734
# Epoch 76, Train Loss: 0.5058, Test Loss: 0.9701
# Epoch 77, Train Loss: 0.5095, Test Loss: 1.2403
# Epoch 78, Train Loss: 0.5232, Test Loss: 1.1237
# Epoch 79, Train Loss: 0.5217, Test Loss: 1.1080
# Epoch 80, Train Loss: 0.5070, Test Loss: 1.0588
# Epoch 81, Train Loss: 0.5122, Test Loss: 0.9289
# Epoch 82, Train Loss: 0.5125, Test Loss: 1.0509
# Epoch 83, Train Loss: 0.5168, Test Loss: 1.1164
# Epoch 84, Train Loss: 0.5080, Test Loss: 1.1877
# Epoch 85, Train Loss: 0.5056, Test Loss: 1.3049
# Epoch 86, Train Loss: 0.5354, Test Loss: 0.9991
# Epoch 87, Train Loss: 0.5151, Test Loss: 0.9834
# Epoch 88, Train Loss: 0.5086, Test Loss: 0.9765
# Epoch 89, Train Loss: 0.5181, Test Loss: 1.3542
# Epoch 90, Train Loss: 0.5068, Test Loss: 1.3308
# Epoch 91, Train Loss: 0.5124, Test Loss: 0.9650
# Epoch 92, Train Loss: 0.5187, Test Loss: 0.9620
# Epoch 93, Train Loss: 0.5278, Test Loss: 0.8735
# Epoch 94, Train Loss: 0.5152, Test Loss: 1.0571
# Epoch 95, Train Loss: 0.5061, Test Loss: 1.0870
# Epoch 96, Train Loss: 0.4977, Test Loss: 1.0923
# Epoch 97, Train Loss: 0.4963, Test Loss: 1.0569
# Epoch 98, Train Loss: 0.5052, Test Loss: 1.1010
# Epoch 99, Train Loss: 0.4968, Test Loss: 1.2565
# Epoch 100, Train Loss: 0.5101, Test Loss: 1.3172

# %%
W = (global_model).get_weight_matrix()
print(W)
# Out:
# Parameter containing:
# tensor([ 0.0016, -0.0009, -0.0542, -0.0017, -0.0081], requires_grad=True)

# %%
A = global_model.get_loading_matrix()
print(A)
# Out:
# Parameter containing:
# tensor([[-3.4085e-02,  4.8005e-03,  6.9445e-02,  ..., -1.4945e-03,
#          -1.7510e-03, -3.3447e-02],
#         [ 4.6706e-04,  3.4096e-02, -2.2089e-03,  ..., -7.9550e-03,
#           2.4566e-03,  7.1943e-02],
#         [ 7.2652e-03, -1.0606e-02, -1.5089e-02,  ..., -3.8865e-03,
#           1.3102e-02, -1.4596e-03],
#         [-3.9644e-02, -4.0236e-02,  2.6854e-02,  ..., -7.9062e-05,
#          -1.6517e-02, -3.5233e-02],
#         [-3.1034e-02, -2.0827e-03,  1.7762e-02,  ...,  2.1347e-02,
#          -2.4774e-02,  2.0238e-03]], requires_grad=True)

# %%
# Assuming you've already loaded your test DataLoader: test_dataloader
mus, sigmas, p_collected, z_collected, true_values, binary_events  = predict(global_model, local_model, event_model, test_dataloader)

# Convert to numpy for easier handling
mus_np = mus.numpy()
sigmas_np = sigmas.numpy()
p_collected = p_collected.numpy()
z_collected = z_collected.numpy()

true_values_np = true_values.numpy()
binary_events_np = binary_events.numpy()

# %%
# print(mus.shape, mus)
# print(sigmas.shape, sigmas)
# print(p_collected.shape, p_collected)
# print(true_values)
# print(binary_events_np)
print(p_collected[:,0])
# Out:
# [4.73616320e-11 1.40347759e-11 1.39969755e-11 ... 1.39967621e-11
#  1.39967621e-11 1.39971888e-11]

# %%
binary_events
# Out:
# tensor([[0.],
#         [0.],
#         [0.],
#         ...,
#         [0.],
#         [0.],
#         [0.]])

# %%
mus_subject = mus_np[:,]
sigmas_subject = sigmas_np[:,0]
true_values_subject = true_values_np
binary_events_subject = binary_events_np
p_subject = p_collected[:,0] # Extracted probabilities


plt.figure(figsize=(20, 6))
plt.plot(mus_subject, label='Predicted $\mu$', color='red')
plt.fill_between(range(len(mus_subject)), (mus_subject - 1.96 * sigmas_subject), (mus_subject + 1.96 * sigmas_subject), color='red', alpha=0.2, label='Uncertainty ($1.96\sigma$)')
plt.plot(true_values_subject, label='True Values', color='blue')

# Plotting the probability as a bar plot at the bottom
bar_height = p_subject  # Scaling factor for visibility
bar_bottom = np.min(true_values_subject)    # Adjust bottom to avoid overlap
# plt.bar(range(len(p_subject)), bar_height,  bottom=bar_bottom, color='gray', label='Event Pred. Probability', width=0.8)

# for i, (value, event) in enumerate(zip(true_values_subject, binary_events_subject)):
#     if event == 1:
#         plt.plot(i, value, 'x', color='black', markersize=8, label='Event = 1' if i == 0 else "")

plt.xticks(range(len(binary_events_subject)))
plt.xlabel('Prediction Time Step')
plt.ylabel('Value')
plt.title('Model Predictions and True Values')
plt.xticks([])

# plt.axhline(y=threshold, color='gray', linestyle='--', linewidth=1, label='Threshold')
# Adjust y-axis limit to make space for the bar plot
# plt.ylim([np.min(bar_bottom)-.5, np.max(true_values_subject) + 1.2])
plt.xlim([0,1005])
# Legend
handles, labels = plt.gca().get_legend_handles_labels()
# Ensure unique labels
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys(), loc='upper left')

plt.tight_layout()
plt.show()
